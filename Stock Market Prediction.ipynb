# %%
import os

print("Current folder:")
print(os.getcwd())

print("\nFiles:")
for root, dirs, files in os.walk("."):
    for file in files:
        print(os.path.join(root, file))
# Out:
# Current folder:
# C:\Users\Granth\anaconda_projects\d732fd7f-dd2e-46e3-8446-b091a2cf8146
#
# Files:
# .\Predict The Stock Market(2nd).ipynb
# .\sp500.xls
# .\Stock Market Prediction.ipynb
# .\.ipynb_checkpoints\Stock Market Prediction-checkpoint.ipynb
